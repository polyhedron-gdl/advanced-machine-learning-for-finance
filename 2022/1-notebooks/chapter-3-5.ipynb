# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/polyhedron-gdl/advanced-machine-learning-for-finance/blob/main/2022/1-notebooks/chapter-3-5.ipynb">
#         <img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# # Understanding Volatility Movements

# %% [markdown]
# ## Introduction

# %% [markdown]
# For our next application of neural networks, some extra background  about derivatives is required.  The Black−Scholes−Merton model relates an option price to the asset price, strike price, dividend yield, riskfree interest rate, time to maturity, and volatility. All of these quantities  are known by analysts except volatility. This means that the Black−Scholes−Merton model in effect provides a one-to-one mapping  of volatility to the price of an option. The volatility that gives the market  price of an option is known as the implied volatility. The moneyness of an option is a measure of how likely an option is to  be exercised. One measure of the moneyness of an option that is frequently used by traders is delta. This is the sensitivity of the option’s  price to the price of the underlying asset. For the Black−Scholes−Merton  model given earlier, the delta of a call option is $𝑒^{−𝑞𝑇𝑁(𝑑_1)}$. For a call  option that is highly unlikely to be exercised (high strike price), delta is  close to zero. As the option become more likely to be exercised (i.e., the  strike price is reduced), delta increases. When the option is almost certain to be exercised delta is close to one.  The volatility surface gives the implied volatility as a function of the  moneyness and time to maturity. If Black−Scholes−Merton was a perfect model for the pricing of options in the market, the implied volatilities for all options would be the same and would never change. In practice, the model is far from perfect and the volatility surface is used by  analysts to monitor the market.
#
# Many different non-linear  shapes for the surface are observed in practice. When the price of an  asset declines, all implied volatilities calculated from options on the asset tend to increase, and vice versa. However, the implied volatilities do  not all change by the same amount. This leads to many variations in the  pattern of implied volatilities.  Understanding how the volatility surface moves is important for a  number of reasons:
#
# - It can help a trader hedge exposures more precisely
#
# - It can help a quant determine a more sophisticated model reflecting how options are priced by the market.
#
# - It can help a trader adjust implied volatilities in a market where  asset prices are changing fast.
#
# A neural network is a natural tool for using empirical data to model volatility surface movements. We will illustrate how it can be used in what  follows.

# %%
#This program takes about 60 minutes to run
#Loading Package
import os

import time
import numpy as np
import scipy as sci
import scipy.io as sio
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow import keras


from numpy.random import seed
seed(100)


import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# ## The Dataset

# %% [markdown]
# Our data consists of call options on the S&P 500 between 2014 and  2019.

# %%
# load raw data
DATA_FOLDER = './data'
FILE_NAME   = 'Implied_Volatility_Data_vFinal.csv'
raw = pd.read_csv(os.path.join(DATA_FOLDER, FILE_NAME))
# check the raw data
print("Size of the dataset (row, col): ", raw.shape)
raw.head(n=5)
# Out:
# Size of the dataset (row, col):  (125700, 5)
#        Date  SPX Return  Time to Maturity in Year     Delta  \
# 0  20140630    0.006678                     0.184  0.745927
# 1  20140630    0.006678                     2.252  0.286911
# 2  20140630    0.006678                     0.124  0.902941
# 3  20140630    0.006678                     2.144  0.910926
# 4  20140630    0.006678                     1.412  0.885760
#
#    Implied Volatility Change
# 0                   0.008462
# 1                   0.002024
# 2                   0.019707
# 3                   0.006424
# 4                   0.005673

# %% [markdown]
# ## Construct the 3 variables for Regression Approach

# %% [markdown]
# There are  three features:
#
# - The return on the S&P 500 from one day to the next (i.e., increase in S&P 500 divided by its level)
#
# - The time to maturity
#
# - The delta of the option  The target is the change in the implied volatility.
#
# The objective is to  minimize the mean squared error between the predicted change in the  implied volatility and the actual change.

# %% [markdown]
# In constructing a machine learning model, it is always useful to have  a simpler model as a benchmark. For this application, we can use the  following model:
#
# $$\text{Expected change in implied volatility} = R \frac{a+b\Delta + c \Delta^2}{\sqrt{T}}$$
#
# where $R$ is the return on the asset (= change in price divided by initial  price), $T$ is the option’s time to maturity, $\Delta$ is the delta measure of the  option’s moneyness, and $a$, $b$, and $c$ are constants. This model was suggested by Hull and White (2017) and is quite popular with practitioner. The $a$, $b$, and $c$ can be estimated by regressing implied volatility  changes against $R/\sqrt{𝑇}$, $R\Delta/\sqrt{T}$, and $R\Delta^2/\sqrt{T}$.

# %%
R     = raw['SPX Return']
RAD_T = np.sqrt(raw['Time to Maturity in Year'])
DELTA = raw['Delta']
# construct the 3 variables for regression
raw['x1'] = R / RAD_T
raw['x2'] = (R / RAD_T) * DELTA
raw['x3'] = (R / RAD_T) * DELTA * DELTA

# Put the X and Y variable in data frame for regression
y = raw['Implied Volatility Change']
X = raw[['x1', 'x2', 'x3','SPX Return','Time to Maturity in Year','Delta']]

# %%
# Divide data into training set and test set(note that random seed is set)
X_train,X_test,y_train,y_test=train_test_split(  X
                                               , y
                                               , test_size    = 0.2
                                               , random_state = 100)

# Divide training set into training and validation set
X_train,X_val,y_train,y_val=train_test_split(  X_train
                                             , y_train
                                             , test_size    = 0.25
                                             , random_state = 100)

# %% [markdown]
# ## Feature Scaling

# %%
# Scale features based on Z-Score
scaler = StandardScaler()
scaler.fit(X_train)


X_scaled_train = scaler.transform(X_train)
X_scaled_vals = scaler.transform(X_val)
X_scaled_test = scaler.transform(X_test)
y_train = np.asarray(y_train)
y_val = np.asarray(y_val)
y_test = np.asarray(y_test)

# %% [markdown]
# ## Run Regression

# %%
# Run the regression on the training data
lr = LinearRegression(fit_intercept=False)
lr.fit(X_scaled_train[:,:3], y_train)

# Get the prediction
y_pred = lr.predict(X_scaled_test[:,:3])

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)

print('Test loss (MSE):', mse)
# Out:
# Test loss (MSE): 7.423167462421238e-05

# %% [markdown]
# ## ML Approach

# %%
# Create ML Model
# Sequential function allows you to define your Neural Network in sequential order
# Within Sequential, use Dense function to define number of nodes, activation 
# function and other related parameters. For more information regrading to activation 
# functoin, please refer to https://keras.io/activations/
model = keras.models.Sequential([Dense(20,activation = "sigmoid",input_shape = (3,))
                                ,Dense(20,activation = "sigmoid")
                                ,Dense(20,activation = "sigmoid")
                                ,Dense(1)])

# Model summary function shows what you created in the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 20)                80
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 941
# Trainable params: 941
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Complie function allows you to choose your measure of loss and optimzer
# For other optimizer, please refer to https://keras.io/optimizers/
model.compile(loss = "mse",optimizer = "Adam")

# %%
# Checkpoint function is used here to periodically save a copy of the model. 
# Currently it is set to save the best performing model
checkpoint_cb = keras.callbacks.ModelCheckpoint("implied_vol_model_vFinal.h5"
                                                , monitor='val_accuracy'
                                                , verbose=1
                                                , save_best_only=True
                                                , mode='max')

# Early stopping allows you to stop your training early if no improvment is 
# shown after certain period. Currently it is set at if no improvement 
# occured in 1000 epochs, at the stop the model will also revert back to 
# the best weight.
early_stopping_cb = keras.callbacks.EarlyStopping(patience = 1000
                                                 ,restore_best_weights = True)

# Remark: checkpoint could be redundant here as early stopping function can also 
# help restoring to the best weight. We put both here just to illustrate different 
# ways to keep the best model

# %%
# train your model
# The fit function allows you to train a NN model. Here we have training data, 
# number of epochs,batch size, validation data, and callbacks as input
# Callback is an optional parameters that allow you to enable tricks for 
# training such as early stopping and checkpoint

# Remarks: Altough we put 50000 epochs here, the model will stop its training 
# once our early stopping criterion is triggered

history=model.fit(  X_scaled_train[:,3:6]
                  , y_train
                  , epochs=5000
                  , batch_size = 128
                  , verbose = 1
                  , validation_data=(X_scaled_vals[:,3:6],y_val)
                  , callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/5000
# 590/590 [==============================] - 2s 2ms/step - loss: 0.0222 - val_loss: 8.5416e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 2/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2662e-05 - val_loss: 8.4923e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 3/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.5754e-05 - val_loss: 8.6479e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 4/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9361e-05 - val_loss: 8.3743e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 5/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2317e-05 - val_loss: 8.3383e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 6/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0379e-05 - val_loss: 8.2674e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 7/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0841e-05 - val_loss: 8.3299e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 8/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0911e-05 - val_loss: 9.1047e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 9/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0136e-05 - val_loss: 8.3993e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 10/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9616e-05 - val_loss: 8.7795e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 11/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2517e-05 - val_loss: 8.5117e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 12/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1765e-05 - val_loss: 8.0854e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 13/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2034e-05 - val_loss: 8.4756e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 14/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1136e-05 - val_loss: 9.1586e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 15/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 9.0220e-05 - val_loss: 8.1549e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 16/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3840e-05 - val_loss: 8.1307e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 17/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.5189e-05 - val_loss: 1.0727e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 18/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3864e-05 - val_loss: 8.0120e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 19/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1162e-05 - val_loss: 8.4463e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 20/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3245e-05 - val_loss: 1.0593e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 21/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1143e-05 - val_loss: 7.9942e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 22/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2124e-05 - val_loss: 8.2171e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 23/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3430e-05 - val_loss: 1.0610e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 24/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.4509e-05 - val_loss: 7.9099e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 25/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0777e-05 - val_loss: 8.2384e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 26/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9591e-05 - val_loss: 8.5141e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 27/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1257e-05 - val_loss: 8.0616e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 28/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0130e-05 - val_loss: 7.9386e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 29/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1037e-05 - val_loss: 7.9370e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 30/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7681e-05 - val_loss: 1.0179e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 31/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1286e-05 - val_loss: 8.0446e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 32/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1810e-05 - val_loss: 9.7580e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 33/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2904e-05 - val_loss: 9.2896e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 34/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.4251e-05 - val_loss: 1.0113e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 35/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3236e-05 - val_loss: 8.7119e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 36/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9018e-05 - val_loss: 8.0105e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 37/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1832e-05 - val_loss: 8.8960e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 38/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3015e-05 - val_loss: 8.0021e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 39/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.5554e-05 - val_loss: 9.9289e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 40/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.7945e-05 - val_loss: 8.2835e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 41/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0149e-05 - val_loss: 7.8765e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 42/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.9275e-05 - val_loss: 1.1246e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 43/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 8.2648e-05 - val_loss: 7.9444e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 44/5000
# 590/590 [==============================] - 1s 3ms/step - loss: 8.0390e-05 - val_loss: 8.6068e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 45/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0028e-05 - val_loss: 7.9228e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 46/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1876e-05 - val_loss: 1.0593e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 47/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0686e-05 - val_loss: 7.8672e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 48/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8346e-05 - val_loss: 8.4847e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 49/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1683e-05 - val_loss: 8.6840e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 50/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3016e-05 - val_loss: 7.9869e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 51/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0040e-05 - val_loss: 1.1040e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 52/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2258e-05 - val_loss: 7.8614e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 53/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1093e-05 - val_loss: 7.9798e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 54/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3139e-05 - val_loss: 8.1761e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 55/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9846e-05 - val_loss: 7.8863e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 56/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8844e-05 - val_loss: 9.8878e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 57/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1441e-05 - val_loss: 7.8922e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 58/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8701e-05 - val_loss: 8.7430e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 59/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0398e-05 - val_loss: 8.0677e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 60/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9962e-05 - val_loss: 8.1430e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 61/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9897e-05 - val_loss: 7.8011e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 62/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0088e-05 - val_loss: 9.9676e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 63/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9202e-05 - val_loss: 7.8890e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 64/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2164e-05 - val_loss: 7.7694e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 65/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8469e-05 - val_loss: 1.0100e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 66/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8980e-05 - val_loss: 7.8593e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 67/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1203e-05 - val_loss: 7.7555e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 68/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0708e-05 - val_loss: 7.8249e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 69/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2781e-05 - val_loss: 7.7539e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 70/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9307e-05 - val_loss: 7.7645e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 71/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0523e-05 - val_loss: 7.7703e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 72/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7805e-05 - val_loss: 8.3702e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 73/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7827e-05 - val_loss: 8.2804e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 74/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8677e-05 - val_loss: 7.8837e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 75/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8952e-05 - val_loss: 8.0475e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 76/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9431e-05 - val_loss: 8.8065e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 77/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0681e-05 - val_loss: 7.7201e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 78/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2706e-05 - val_loss: 7.7937e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 79/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6586e-05 - val_loss: 8.3743e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 80/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9070e-05 - val_loss: 7.7778e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 81/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8529e-05 - val_loss: 7.7905e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 82/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9132e-05 - val_loss: 8.3390e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 83/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3811e-05 - val_loss: 9.2578e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 84/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1887e-05 - val_loss: 7.9870e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 85/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9602e-05 - val_loss: 8.4514e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 86/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.3741e-05 - val_loss: 7.8381e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 87/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9758e-05 - val_loss: 9.4187e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 88/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8791e-05 - val_loss: 7.7154e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 89/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0634e-05 - val_loss: 8.0510e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 90/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9254e-05 - val_loss: 9.0513e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 91/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9196e-05 - val_loss: 7.7640e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 92/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8429e-05 - val_loss: 7.7966e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 93/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6808e-05 - val_loss: 7.9815e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 94/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6452e-05 - val_loss: 7.7030e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 95/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.8827e-05 - val_loss: 7.7490e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 96/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8467e-05 - val_loss: 7.9335e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 97/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8235e-05 - val_loss: 7.7242e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 98/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8010e-05 - val_loss: 7.8578e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 99/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8396e-05 - val_loss: 8.5188e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 100/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7132e-05 - val_loss: 8.2816e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 101/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8744e-05 - val_loss: 8.0245e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 102/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9142e-05 - val_loss: 7.8283e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 103/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8544e-05 - val_loss: 8.0303e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 104/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1492e-05 - val_loss: 7.6799e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 105/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7981e-05 - val_loss: 7.6755e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 106/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8422e-05 - val_loss: 7.6845e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 107/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8342e-05 - val_loss: 7.9401e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 108/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1593e-05 - val_loss: 8.8730e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 109/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8272e-05 - val_loss: 8.5582e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 110/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8345e-05 - val_loss: 7.7712e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 111/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8518e-05 - val_loss: 1.0182e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 112/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9910e-05 - val_loss: 7.9126e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 113/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0363e-05 - val_loss: 8.0615e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 114/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6610e-05 - val_loss: 7.7269e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 115/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9755e-05 - val_loss: 7.6777e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 116/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.1156e-05 - val_loss: 7.8258e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 117/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5964e-05 - val_loss: 7.6904e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 118/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.2963e-05 - val_loss: 7.7809e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 119/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6253e-05 - val_loss: 8.4011e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 120/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7593e-05 - val_loss: 8.1941e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 121/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7340e-05 - val_loss: 7.6765e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 122/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9567e-05 - val_loss: 8.5293e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 123/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0923e-05 - val_loss: 7.6605e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 124/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9716e-05 - val_loss: 9.7557e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 125/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9313e-05 - val_loss: 8.1310e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 126/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6789e-05 - val_loss: 7.8784e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 127/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9100e-05 - val_loss: 7.6325e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 128/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8820e-05 - val_loss: 8.3343e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 129/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7748e-05 - val_loss: 8.0296e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 130/5000
# 590/590 [==============================] - 1s 3ms/step - loss: 7.6945e-05 - val_loss: 7.8652e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 131/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7734e-05 - val_loss: 7.9311e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 132/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 8.1794e-05 - val_loss: 7.6120e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 133/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.6567e-05 - val_loss: 7.6497e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 134/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5993e-05 - val_loss: 9.7062e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 135/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9300e-05 - val_loss: 7.6447e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 136/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8201e-05 - val_loss: 7.9061e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 137/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7858e-05 - val_loss: 7.6793e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 138/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6731e-05 - val_loss: 8.0628e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 139/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0994e-05 - val_loss: 7.7836e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 140/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7137e-05 - val_loss: 8.6818e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 141/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8965e-05 - val_loss: 8.2475e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 142/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7881e-05 - val_loss: 7.8881e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 143/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7790e-05 - val_loss: 8.3330e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 144/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5194e-05 - val_loss: 8.0084e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 145/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7121e-05 - val_loss: 7.6021e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 146/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8414e-05 - val_loss: 7.6316e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 147/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6910e-05 - val_loss: 7.5685e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 148/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8400e-05 - val_loss: 7.5979e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 149/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7133e-05 - val_loss: 9.4342e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 150/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0198e-05 - val_loss: 8.0265e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 151/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0326e-05 - val_loss: 7.7668e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 152/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8653e-05 - val_loss: 7.6413e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 153/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8708e-05 - val_loss: 7.6281e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 154/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8494e-05 - val_loss: 7.7032e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 155/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6845e-05 - val_loss: 7.5571e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 156/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7257e-05 - val_loss: 8.7350e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 157/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0804e-05 - val_loss: 8.0924e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 158/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5222e-05 - val_loss: 7.6631e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 159/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5378e-05 - val_loss: 7.5980e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 160/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7025e-05 - val_loss: 7.5838e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 161/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6220e-05 - val_loss: 7.5505e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 162/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3979e-05 - val_loss: 7.5421e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 163/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6383e-05 - val_loss: 7.6450e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 164/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6354e-05 - val_loss: 7.6127e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 165/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4295e-05 - val_loss: 7.5667e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 166/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5920e-05 - val_loss: 8.5878e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 167/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7093e-05 - val_loss: 9.0969e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 168/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6349e-05 - val_loss: 7.5530e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 169/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8057e-05 - val_loss: 8.1565e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 170/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7722e-05 - val_loss: 7.6391e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 171/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5003e-05 - val_loss: 8.0593e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 172/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4601e-05 - val_loss: 7.6622e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 173/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6484e-05 - val_loss: 8.2907e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 174/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8275e-05 - val_loss: 7.5203e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 175/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.7631e-05 - val_loss: 7.6007e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 176/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5877e-05 - val_loss: 7.6775e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 177/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4785e-05 - val_loss: 1.0204e-04
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 178/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0955e-05 - val_loss: 7.5422e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 179/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5043e-05 - val_loss: 9.6012e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 180/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7025e-05 - val_loss: 7.4937e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 181/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.9140e-05 - val_loss: 7.9395e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 182/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6424e-05 - val_loss: 7.6781e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 183/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4165e-05 - val_loss: 7.5971e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 184/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8063e-05 - val_loss: 9.6886e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 185/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6288e-05 - val_loss: 7.5434e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 186/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8019e-05 - val_loss: 7.7656e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 187/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8253e-05 - val_loss: 7.5190e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 188/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5078e-05 - val_loss: 7.8762e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 189/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5411e-05 - val_loss: 7.5476e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 190/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6447e-05 - val_loss: 7.4963e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 191/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6161e-05 - val_loss: 7.5840e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 192/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4593e-05 - val_loss: 7.9870e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 193/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5938e-05 - val_loss: 9.3079e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 194/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6726e-05 - val_loss: 7.4729e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 195/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6853e-05 - val_loss: 7.5049e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 196/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7136e-05 - val_loss: 7.8574e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 197/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6824e-05 - val_loss: 7.5867e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 198/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5260e-05 - val_loss: 7.6666e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 199/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8071e-05 - val_loss: 7.4509e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 200/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7274e-05 - val_loss: 7.4442e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 201/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4386e-05 - val_loss: 7.8845e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 202/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6638e-05 - val_loss: 7.5199e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 203/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4909e-05 - val_loss: 7.4876e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 204/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4221e-05 - val_loss: 8.3919e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 205/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8663e-05 - val_loss: 7.7502e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 206/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7905e-05 - val_loss: 7.6287e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 207/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7925e-05 - val_loss: 7.4879e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 208/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5467e-05 - val_loss: 7.4324e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 209/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5015e-05 - val_loss: 7.7277e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 210/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 8.0580e-05 - val_loss: 7.5023e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 211/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4017e-05 - val_loss: 8.6310e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 212/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 8.0946e-05 - val_loss: 7.6828e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 213/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6542e-05 - val_loss: 7.8441e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 214/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7176e-05 - val_loss: 7.4416e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 215/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4719e-05 - val_loss: 7.5038e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 216/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4783e-05 - val_loss: 7.5344e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 217/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5570e-05 - val_loss: 7.8254e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 218/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8250e-05 - val_loss: 8.1432e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 219/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.8272e-05 - val_loss: 7.6255e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 220/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6540e-05 - val_loss: 7.4637e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 221/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5064e-05 - val_loss: 7.4002e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 222/5000
# 590/590 [==============================] - 2s 4ms/step - loss: 7.7104e-05 - val_loss: 7.6663e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 223/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3647e-05 - val_loss: 7.4293e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 224/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3055e-05 - val_loss: 7.5302e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 225/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6523e-05 - val_loss: 7.5292e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 226/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3241e-05 - val_loss: 9.6439e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 227/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7748e-05 - val_loss: 7.3993e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 228/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3773e-05 - val_loss: 7.4457e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 229/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4537e-05 - val_loss: 8.6688e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 230/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5670e-05 - val_loss: 7.3804e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 231/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.6681e-05 - val_loss: 7.4298e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 232/5000
# 590/590 [==============================] - 2s 3ms/step - loss: 7.7630e-05 - val_loss: 8.1488e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 233/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6049e-05 - val_loss: 7.5966e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 234/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3025e-05 - val_loss: 7.4523e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 235/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5600e-05 - val_loss: 7.5831e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 236/5000
# 590/590 [==============================] - 1s 1ms/step - loss: 7.6405e-05 - val_loss: 8.1825e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 237/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4105e-05 - val_loss: 7.3861e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 238/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5662e-05 - val_loss: 7.4753e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 239/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5201e-05 - val_loss: 7.5626e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 240/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5697e-05 - val_loss: 8.0337e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 241/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5273e-05 - val_loss: 7.8756e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 242/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.6606e-05 - val_loss: 8.3111e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 243/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.7028e-05 - val_loss: 7.5157e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 244/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3126e-05 - val_loss: 7.3616e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 245/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3610e-05 - val_loss: 7.5548e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 246/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3616e-05 - val_loss: 7.3701e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 247/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3418e-05 - val_loss: 7.4193e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 248/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5330e-05 - val_loss: 7.9007e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 249/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4867e-05 - val_loss: 7.7133e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 250/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.5431e-05 - val_loss: 7.5333e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 251/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3365e-05 - val_loss: 7.3447e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 252/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3347e-05 - val_loss: 7.9143e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 253/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4828e-05 - val_loss: 7.7464e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 254/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3614e-05 - val_loss: 7.5668e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 255/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.3742e-05 - val_loss: 7.3728e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 256/5000
# 590/590 [==============================] - 1s 2ms/step - loss: 7.4822e-05 - val_loss: 7.5937e-05
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# Epoch 257/5000
# 331/590 [===============>..............] - ETA: 0s - loss: 7.4963e-05

# %%
# Load the best model you saved and calcuate MSE for testing set

model = keras.models.load_model("implied_vol_model_vFinal.h5")
mse_test = model.evaluate(X_scaled_test[:,3:6],y_test,verbose=0)

print('Test Loss(MSE):', mse_test)
# Out:
# Test Loss(MSE): 7.103688403731212e-05

# %%
# Calculate Gain Ratio

gain = 1 - mse_test/mse 

print('Gain Ratio:', gain)
# Out:
# Gain Ratio: 0.04303810473188774

# %% [markdown]
# ## Review your results and export training history

# %%
# Plot training history

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0.0000,0.00015)
plt.show()

#Export your training history for MSE
output = pd.DataFrame(history.history)
output.to_csv("mse_overtime.csv")
